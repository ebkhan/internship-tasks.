# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading data set 
Amount=pd.read_csv(r"C:\Users\EB\PY\Amount.csv")

# %%
#Used for displaying data set in file
print(Amount)
# Out:
#      ID           Name  Amount  Payement     City
# 0   521        Ibrahim     203      Card  Newyork
# 1   431         Hassan     444      Cash   Berlin
# 2   234         Junaid     519      Card   London
# 3   355          Javed     630      Cash    Paris
# 4   265  Saige Fuentes     780      Card   London
# 5   144          Zadie     800      Cash  Newyork
# 6   532        Luella      920      Card    Paris
# 7   218       Cordelia     430      Cash   Berlin
# 8   129          James     650      Cash  Newyork
# 9   310        Eleanor     560  E-wallet   London
# 10  411           Bowe     900      Cash    Tokyo
# 11  512         Lucian    1000      Card   Berlin
# 12  613            Lee    1050  E-wallet   London
# 13  714           Tait    1100      Card    Paris
# 14  415          Shane    1200      Cash    Tokyo
# 15  816         Travis    1300  E-wallet    Paris
# 16  918          Marsh    1400      Card    Cario
# 17  653          Kevin    1500  E-wallet  Newyork
# ...

# %%
# Used to display dimession of rows and columns
print(Amount.shape)
# Out:
# (30, 5)

# %%
# Used to display column labels/name
print(Amount.columns)
# Out:
# Index(['ID', 'Name', 'Amount', 'Payement', 'City'], dtype='object')

# %%
# Used to display first few row headers
print(Amount.head())
# Out:
#     ID           Name  Amount Payement     City
# 0  521        Ibrahim     203     Card  Newyork
# 1  431         Hassan     444     Cash   Berlin
# 2  234         Junaid     519     Card   London
# 3  355          Javed     630     Cash    Paris
# 4  265  Saige Fuentes     780     Card   London

# %%
#Scatter plot to analyze relationships between variables.
sns.scatterplot(x="Amount", y="City", data=Amount ,hue="Payement")
# Out:
# <Axes: xlabel='Amount', ylabel='City'>

# %%
#Histogram to examine data distribution.
sns.histplot(Amount['Amount'], kde=True, bins=10)
# Out:
# <Axes: xlabel='Amount', ylabel='Count'>

# %%
#Box plot to detect outliers and spread of values..
sns.boxplot(x="City", y="Amount", data=Amount, hue="Payement",palette="YlGnBu")
# Out:
# <Axes: xlabel='City', ylabel='Amount'>
